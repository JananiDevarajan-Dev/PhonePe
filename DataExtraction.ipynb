# %%
#Required libraries for the program

import pandas as pd
import json
import os
from sqlalchemy import create_engine,text
import urllib.parse

# %%
# Database connection details
username = "root"          # your MySQL username
password = urllib.parse.quote_plus("Password@0274")  # encode special characters  # your MySQL password
host = "localhost"         # local system
port = 3306                # default MySQL port
database = "Phonepe"        # your database name

# Create connection engine
engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 2.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.7 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
#This is to direct the path to get the data as states


path="F:/Python_WC/PhonePay/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe Agg_Transaction

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Transaction=pd.DataFrame(clm)


# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Agg_Transaction.to_sql('Agg_Transaction', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10752\852545058.py:48: UserWarning: The provided table name 'Agg_Transaction' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Agg_Transaction.to_sql('Agg_Transaction', con=engine, if_exists='append', index=False)

# %%
Agg_Transaction
# Out:
#                           State  Year  Quater           Transacion_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 5029                west-bengal  2024       4         Merchant payments
# 5030                west-bengal  2024       4     Peer-to-peer payments
# 5031                west-bengal  2024       4  Recharge & bill payments
# 5032                west-bengal  2024       4        Financial Services
# 5033                west-bengal  2024       4                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# ...

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 3.2 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.0 MB 3.0 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.0 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.0 MB 2.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.0 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.7/11.0 MB 2.9 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/11.0 MB 2.9 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/11.0 MB 3.0 MB/s eta 0:00:03
#    --------------------- ------------------ 5.8/11.0 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.0 MB 3.2 MB/s eta 0:00:02
# ...

# %%
pip install os
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
#This is to direct the path to get the data as states
path="F:/Python_WC/PhonePay/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe Agg_Transaction

#clm1={'State':[], 'Year':[],'Quater':[],'RegisteredUsers':[], 'AppOpens':[], 'Brand':[], 'Count':[]}
clm1={'State':[], 'Year':[],'Quater':[],'RegisteredUsers':[], 'AppOpens':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
       
        for k in Agg_yr_list:
            p_k=p_j+k
            
            Data=open(p_k,'r')
            
            D=json.load(Data)
            
            registeredUsers = D['data']['aggregated']['registeredUsers']
            appOpens = D['data']['aggregated']['appOpens']
            clm1['RegisteredUsers'].append(registeredUsers)
            clm1['AppOpens'].append(appOpens)
            '''for b in D['data']['usersByDevice'] or []:
              brand=b['brand'] 
              count=b['count'] 
              clm1['Brand'].append(brand)
              clm1['Count'].append(count)'''
            clm1['State'].append(i)
            clm1['Year'].append(j)
            clm1['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_User=pd.DataFrame(clm1)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Agg_User.to_sql('Agg_User', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10752\3863131114.py:43: UserWarning: The provided table name 'Agg_User' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Agg_User.to_sql('Agg_User', con=engine, if_exists='append', index=False)

# %%
Agg_User
# Out:
#                           State  Year  Quater  RegisteredUsers    AppOpens
# 0     andaman-&-nicobar-islands  2018       1             6740           0
# 1     andaman-&-nicobar-islands  2018       2             9405           0
# 2     andaman-&-nicobar-islands  2018       3            12149           0
# 3     andaman-&-nicobar-islands  2018       4            15222           0
# 4     andaman-&-nicobar-islands  2019       1            18596           0
# ...                         ...   ...     ...              ...         ...
# 1003                west-bengal  2023       4         30064546  1467442959
# 1004                west-bengal  2024       1         31306843   633526507
# 1005                west-bengal  2024       2         32540397   704276274
# 1006                west-bengal  2024       3         33612828   709864323
# 1007                west-bengal  2024       4         34750181  1994940763
#
# [1008 rows x 5 columns]

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe Agg_Transaction

clm2={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm2['Transacion_type'].append(Name)
              clm2['Transacion_count'].append(count)
              clm2['Transacion_amount'].append(amount)
              clm2['State'].append(i)
              clm2['Year'].append(j)
              clm2['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Insurance=pd.DataFrame(clm2)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Agg_Insurance.to_sql('Agg_Insurance', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10752\1238993313.py:37: UserWarning: The provided table name 'Agg_Insurance' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Agg_Insurance.to_sql('Agg_Insurance', con=engine, if_exists='append', index=False)

# %%
Agg_Insurance
# Out:
#                          State  Year  Quater Transacion_type  \
# 0    andaman-&-nicobar-islands  2020       2       Insurance
# 1    andaman-&-nicobar-islands  2020       3       Insurance
# 2    andaman-&-nicobar-islands  2020       4       Insurance
# 3    andaman-&-nicobar-islands  2021       1       Insurance
# 4    andaman-&-nicobar-islands  2021       2       Insurance
# ..                         ...   ...     ...             ...
# 677                west-bengal  2023       4       Insurance
# 678                west-bengal  2024       1       Insurance
# 679                west-bengal  2024       2       Insurance
# 680                west-bengal  2024       3       Insurance
# 681                west-bengal  2024       4       Insurance
#
#      Transacion_count  Transacion_amount
# 0                   6             1360.0
# 1                  41            15380.0
# 2                 124           157975.0
# 3                 225           244266.0
# ...

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/map/transaction/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm3={'State':[], 'Year':[],'Quater':[],'District Name':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm3['District Name'].append(Name)
              clm3['Transacion_count'].append(count)
              clm3['Transacion_amount'].append(amount)
              clm3['State'].append(i)
              clm3['Year'].append(j)
              clm3['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Transaction=pd.DataFrame(clm3)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Map_Transaction.to_sql('Map_Transaction', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10752\746261054.py:38: UserWarning: The provided table name 'Map_Transaction' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Map_Transaction.to_sql('Map_Transaction', con=engine, if_exists='append', index=False)

# %%
Map_Transaction
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20599                west-bengal  2024       4
# 20600                west-bengal  2024       4
# 20601                west-bengal  2024       4
# 20602                west-bengal  2024       4
# 20603                west-bengal  2024       4
#
#                            District Name  Transacion_count  Transacion_amount
# 0      north and middle andaman district               442       9.316631e+05
# 1                 south andaman district              5688       1.256025e+07
# 2                      nicobars district               528       1.139849e+06
# 3      north and middle andaman district               825       1.317863e+06
# ...

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/map/insurance/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm4={'State':[], 'Year':[],'Quater':[],'District Name':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm4['District Name'].append(Name)
              clm4['Transacion_count'].append(count)
              clm4['Transacion_amount'].append(amount)
              clm4['State'].append(i)
              clm4['Year'].append(j)
              clm4['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Insurance=pd.DataFrame(clm4)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Map_Insurance.to_sql('Map_Insurance', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10752\2838400501.py:38: UserWarning: The provided table name 'Map_Insurance' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Map_Insurance.to_sql('Map_Insurance', con=engine, if_exists='append', index=False)

# %%
Map_Insurance
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 13871                west-bengal  2024       4
# 13872                west-bengal  2024       4
# 13873                west-bengal  2024       4
# 13874                west-bengal  2024       4
# 13875                west-bengal  2024       4
#
#                            District Name  Transacion_count  Transacion_amount
# 0                 south andaman district                 3              795.0
# 1                      nicobars district                 3              565.0
# 2      north and middle andaman district                 1              281.0
# 3                 south andaman district                35            13651.0
# ...

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/map/user/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm5={'State':[], 'Year':[],'Quater':[],'District Name':[], 'RegisteredUsers':[], 'AppOpens':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for state, values in D['data']['hoverData'].items() or []:
                districtnames=state
                registeredUsers=values['registeredUsers']
                appOpens=values['appOpens']
                clm5['District Name'].append(districtnames)
                clm5['RegisteredUsers'].append(registeredUsers)
                clm5['AppOpens'].append(appOpens)
                clm5['State'].append(i)
                clm5['Year'].append(j)
                clm5['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_User=pd.DataFrame(clm5)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Map_User.to_sql('Map_User', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_10752\2617811007.py:38: UserWarning: The provided table name 'Map_User' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Map_User.to_sql('Map_User', con=engine, if_exists='append', index=False)

# %%
Map_User
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20603                west-bengal  2024       4
# 20604                west-bengal  2024       4
# 20605                west-bengal  2024       4
# 20606                west-bengal  2024       4
# 20607                west-bengal  2024       4
#
#                            District Name  RegisteredUsers   AppOpens
# 0      north and middle andaman district              632          0
# 1                 south andaman district             5846          0
# 2                      nicobars district              262          0
# 3      north and middle andaman district              911          0
# ...

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm6={'State':[], 'Year':[],'Quater':[],'District_Name':[],'Pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            
            for z in D['data']['districts']:
              districts=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              pincode="none"
              clm6['District_Name'].append(districts)
              clm6['Pincodes'].append(pincode)
              clm6['Transacion_count'].append(count)
              clm6['Transacion_amount'].append(amount)
              clm6['State'].append(i)
              clm6['Year'].append(j)
              clm6['Quater'].append(int(k.strip('.json')))

              for p in D['data']['pincodes']:
                pincodes=p['entityName']
                count=p['metric']['count']
                amount=p['metric']['amount']
                district='none'
                clm6['District_Name'].append(district)
                clm6['Pincodes'].append(pincodes)
                clm6['Transacion_count'].append(count)
                clm6['Transacion_amount'].append(amount)
                clm6['State'].append(i)
                clm6['Year'].append(j)
                clm6['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Transaction=pd.DataFrame(clm6)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Top_Transaction.to_sql('Top_Transaction', con=engine, if_exists='append', index=False)

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_1264\567922532.py:54: UserWarning: The provided table name 'Top_Transaction' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Top_Transaction.to_sql('Top_Transaction', con=engine, if_exists='append', index=False)

# %%
Top_Transaction.isnone()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1264\3035961008.py in ?()
# ----> 1 Top_Transaction.isnone()
#
# c:\Users\thiya\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isnone'

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/top/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm7={'State':[], 'Year':[],'Quater':[],'District_Name':[],'Pincodes':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            
            for z in D['data']['districts']:
              districts=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              pincode="none"
              clm7['District_Name'].append(districts)
              clm7['Pincodes'].append(pincode)
              clm7['Transacion_count'].append(count)
              clm7['Transacion_amount'].append(amount)
              clm7['State'].append(i)
              clm7['Year'].append(j)
              clm7['Quater'].append(int(k.strip('.json')))

              for p in D['data']['pincodes']:
                pincodes=p['entityName']
                count=p['metric']['count']
                amount=p['metric']['amount']
                district='none'
                clm7['District_Name'].append(district)
                clm7['Pincodes'].append(pincodes)
                clm7['Transacion_count'].append(count)
                clm7['Transacion_amount'].append(amount)
                clm7['State'].append(i)
                clm7['Year'].append(j)
                clm7['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_Insurance=pd.DataFrame(clm7)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Top_Insurance.to_sql('Top_Insurance', con=engine, if_exists='append', index=False)

#print("Data inserted successfully!")
# Out:
# ✅ CSV file created successfully!

# %%
Top_Transaction.head(20)
# Out:
#                         State  Year  Quater  District Name Pincodes  \
# 0   andaman-&-nicobar-islands  2020       2       nicobars     none
# 1   andaman-&-nicobar-islands  2020       2           none   744301
# 2   andaman-&-nicobar-islands  2020       2           none   744104
# 3   andaman-&-nicobar-islands  2020       2           none   744101
# 4   andaman-&-nicobar-islands  2020       2  south andaman     none
# 5   andaman-&-nicobar-islands  2020       2           none   744301
# 6   andaman-&-nicobar-islands  2020       2           none   744104
# 7   andaman-&-nicobar-islands  2020       2           none   744101
# 8   andaman-&-nicobar-islands  2020       3  south andaman     none
# 9   andaman-&-nicobar-islands  2020       3           none   744112
# 10  andaman-&-nicobar-islands  2020       3           none   744105
# 11  andaman-&-nicobar-islands  2020       3           none   744101
# 12  andaman-&-nicobar-islands  2020       3           none   744206
# ...

# %%
#This is to direct the path to get the data as states

path="F:/Python_WC/PhonePay/pulse/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm8={'State':[], 'Year':[],'Quater':[],'District_Name':[],'Pincodes':[], 'RegisteredUsers':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            
            for z in D['data']['districts']:
              districts=z['name']
              registeredUsers=z['registeredUsers']
              pincode="none"
              clm8['District_Name'].append(districts)
              clm8['Pincodes'].append(pincode)
              clm8['RegisteredUsers'].append(registeredUsers)
              clm8['State'].append(i)
              clm8['Year'].append(j)
              clm8['Quater'].append(int(k.strip('.json')))

              for p in D['data']['pincodes']:
                pincodes=p['name']
                registeredUsers=p['registeredUsers']
                district='none'
                clm8['District_Name'].append(district)
                clm8['Pincodes'].append(pincodes)
                clm8['RegisteredUsers'].append(registeredUsers)
                clm8['State'].append(i)
                clm8['Year'].append(j)
                clm8['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Top_User=pd.DataFrame(clm8)

# Insert DataFrame into MySQL (replace 'transactions_table' with your table name)
Top_User.to_sql('Top_User', con=engine, if_exists='append', index=False)
print("Data inserted successfully!")
# Out:
# Data inserted successfully!
# C:\Users\thiya\AppData\Local\Temp\ipykernel_1264\3314340032.py:50: UserWarning: The provided table name 'Top_User' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   Top_User.to_sql('Top_User', con=engine, if_exists='append', index=False)

# %%
Top_User.head(20)
# Out:
#                         State  Year  Quater             District Name  \
# 0   andaman-&-nicobar-islands  2018       1             south andaman
# 1   andaman-&-nicobar-islands  2018       1                      none
# 2   andaman-&-nicobar-islands  2018       1                      none
# 3   andaman-&-nicobar-islands  2018       1                      none
# 4   andaman-&-nicobar-islands  2018       1                      none
# 5   andaman-&-nicobar-islands  2018       1                      none
# 6   andaman-&-nicobar-islands  2018       1                      none
# 7   andaman-&-nicobar-islands  2018       1                      none
# 8   andaman-&-nicobar-islands  2018       1                      none
# 9   andaman-&-nicobar-islands  2018       1                      none
# 10  andaman-&-nicobar-islands  2018       1                      none
# 11  andaman-&-nicobar-islands  2018       1  north and middle andaman
# ...
